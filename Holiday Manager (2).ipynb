# %%
#variables go here
choice = 0

# %%
import json
import datetime

# %%
#data scraping:
from bs4 import BeautifulSoup
import requests

def getHTML(url):
    response = requests.get(url)
    return response.content

html = getHTML("https://www.timeanddate.com/holidays/us/")


soup = BeautifulSoup(html, 'html.parser')

table = soup.find('table', attrs = {'class': "table table--left table--inner-borders-rows table--full-width table--sticky table--holidaycountry"})

A = []
B = []
for row in table.find_all_next('tr'):
    datecells = row.find_all('th')
    if len(datecells) ==1:
        A.append(datecells[0].find(text=True))
    namecells = row.find_all('td')
    if len(namecells)==4:
        B.append(namecells[1].find(text=True))

# %%
#Holday Class

class Holiday:
    def __init__(self, name, date):
        self.name = name
        self.date = date
        
    def get_name(self):
        return self._name
    
    def set_name(self):
        self.name = [name]
        
    def get_date(self):
        return self.date
    
    def set_date(self):
        self.date = [date]
        
    def display_holiday(self):
        print(name, date)
        
    def write_holiday(self, name, date):
        A.append(date)
        B.append(name) 
        

    def remove_holiday(self, name):
        index = B.index(name)
        B.pop(index)
        A.pop(index)

# %%
#Choice 1 section
def AddHolidays():
    print("ADD HOLIDAYS")
    print("--------------------")
    print("What is the name of the holiday you would like to add?")
    name = input()
    print("What is the date of that holiday?")
    date = input()
    print("Are you sure you'd like to add this? Please enter y for yes and n for no.")
    addchoice = input()
    if addchoice == 'y':
        print("Got it! Adding the holiday...")
        addholiday = Holiday(name, date)
        Holiday(name, date).write_holiday(name, date)
        print(A)
        print(B)
        print("Added! What else would you like to do?")
    elif addchoice == 'n':
        print("Understood. Anything else you want to do?")
    else:
        print("Sorry, I couldn't understand that. Would you like to do anything else?")

# %%
#Choice 2 section
def DeleteHolidays(func):
    print("DELETE HOLIDAYS")
    print("--------------------")
    print("What is the name of the holiday you'd like to delete?")
    name = input()
    print("Do you know what the date for this would be? Please input one")
    date = input()
    Holiday(name, date).remove_holiday(name)
    func()

# %%
#Choice 3 section
def SaveHolidays():
    print("SAVE HOLIDAYS")
    print("---------------------")
    print("Would you like to save your changes to a copy of the file? Press y for yes, and n for no.")
    savechoice = input()
    if savechoice == 'y':
        savedict = list()
        for i in range(len(A)):
            dict={"name": B[i], "date": A[i]}
            savedict.append(dict)
        filename = 'holidays.json'
        with open(filename, 'w') as json_file:
            json.dump(savedict, json_file, indent = 3, separators=(',',': '))
            print("All done!! Your changes have been saved.")
    elif savechoice == 'n':
        print("Alright! Your save has been cancelled.")
    else:
        print("That was not a valid input. Please use a valid input next time.")

# %%
#Choice 4 section
def ViewHolidays():
    print("VIEW HOLIDAYS")
    print("---------------------")
    print("What week of holidays would you like to view? For the current week, leave it blank.")
    week = input()
    #datetime.strptime(f'yr,wk).date()
    if week is None:
        print("Here are this week's holidays, and the weather:")
        open('holidays.json', 'r')
        filename = 'holidays.json'
        listObj = []
        with open('holidays.json') as fp:
            weather = 'api.openweathermap.org/data/2.5/forecast?q={Minneapolis}&appid={1b406ed29a106e93ed43408e778ecd5d}'
            print(weather)
    else:
        print("Here are the holidays for the week you requested.")
        listObj = []
        with open('holidays.json') as fp:
            listObj = json.load(fp)
            date.isocalendar(listObj)
        monthday = list()
        D = []
        D.append(date)
        for i in range(len(listObj)):
            dict={"Date": D[i]}
        result = monthday.append(dict)
        
        print("Here are the holidays that you requested.")
        print(result)
            
    print("What else would you like to do?")

# %%
#Choice 5 section
def ExitProgram():
    global choice
    while choice == 5:
        print("EXIT PROGRAM")
        print("---------------------")
        print("Are you sure you want to exit? [y/n]")
        exit = input()
        if exit == 'y':
            print("Thank you for using Holiday Manager! See you again soon.")
            choice = 6
        elif exit == 'n':
            print("Alright, what would you like to do now?")

# %%
while choice != 6:
    print(range(len(A)))
    print("Welcome to the holiday manager.")
    print("What would you like to do?")
    print("1. Add a Holiday")
    print("2. Remove a Holiday")
    print("3. Save Holiday List")
    print("4. View Holidays")
    print("5. Exit")
    print("Choosing 6 will force quit the program, and your progress will be lost. ")
    choice = int(input("Please print the number of your choice."))
    if choice == 1:
        AddHolidays()   
    elif choice == 2:
        @DeleteHolidays
        def DeleteMsg():
            print("Your entry has been deleted. Thank you.")
    elif choice == 3:
        SaveHolidays()
    elif choice == 4:
        ViewHolidays()
    elif choice == 5:
        ExitProgram()
# Out:
# range(0, 500)
# Welcome to the holiday manager.
# What would you like to do?
# 1. Add a Holiday
# 2. Remove a Holiday
# 3. Save Holiday List
# 4. View Holidays
# 5. Exit
# Choosing 6 will force quit the program, and your progress will be lost.
# Please print the number of your choice.1
# ADD HOLIDAYS
# --------------------
# What is the name of the holiday you would like to add?
# birthday
# What is the date of that holiday?
# april 3
# Are you sure you'd like to add this? Please enter y for yes and n for no.
# y
# Got it! Adding the holiday...
# ['Jan 1', 'Jan 1', 'Jan 4', 'Jan 6', 'Jan 7', 'Jan 7', 'Jan 13', 'Jan 14', 'Jan 17', 'Jan 18', 'Jan 18', 'Jan 18', 'Jan 18', 'Jan 18', 'Jan 18', 'Jan 19', 'Jan 19', 'Jan 20', 'Jan 20', 'Jan 24', 'Jan 26', 'Jan 27', 'Jan 28', 'Jan 29', 'Jan 31', 'Feb 1', 'Feb 1', 'Feb 2', 'Feb 2', 'Feb 4', 'Feb 4', 'Feb 4', 'Feb 5', 'Feb 6', 'Feb 7', 'Feb 10', 'Feb 11', 'Feb 11', 'Feb 12', 'Feb 12', 'Feb 12', 'Feb 13', 'Feb 14', 'Feb 14', 'Feb 15', 'Feb 15', 'Feb 15', 'Feb 15', 'Feb 15', 'Feb 16', 'Feb 16', 'Feb 16', 'Feb 17', 'Feb 20', 'Feb 21', 'Feb 25', 'Feb 26', 'Feb 28', 'Mar 1', 'Mar 1', 'Mar 1', 'Mar 1', 'Mar 1', 'Mar 1', 'Mar 2', 'Mar 2', 'Mar 2', 'Mar 3', 'Mar 5', 'Mar 8', 'Mar 11', 'Mar 11', 'Mar 11', 'Mar 14', 'Mar 17', 'Mar 17', 'Mar 20', 'Mar 20', 'Mar 20', 'Mar 21', 'Mar 21', 'Mar 21', 'Mar 21', 'Mar 21', 'Mar 22', 'Mar 23', 'Mar 24', 'Mar 24', 'Mar 25', 'Mar 25', 'Mar 25', 'Mar 26', 'Mar 27', 'Mar 27', 'Mar 28', 'Mar 28', 'Mar 28', 'Mar 29', 'Mar 29', 'Mar 30', 'Mar 31', 'Apr 1', 'Apr 1', 'Apr 2', 'Apr 2', 'Apr 2', 
6', 'Sep 7', 'Sep 7', 'Sep 7', 'Sep 8', 'Sep 9', 'Sep 9', 'Sep 10', 'Sep 10', 'Sep 11', 'Sep 11', 'Sep 11', 'Sep 12', 'Sep 12', 'Sep 13', 'Sep 15', 'Sep 16', 'Sep 16', 'Sep 16', 'Sep 17', 'Sep 17', 'Sep 17', 'Sep 17', 'Sep 18', 'Sep 18', 'Sep 18', 'Sep 21', 'Sep 21', 'Sep 22', 'Sep 22', 'Sep 23', 'Sep 23', 'Sep 24', 'Sep 24', 'Sep 24', 'Sep 26', 'Sep 26', 'Sep 27', 'Sep 27', 'Sep 27', 'Sep 28', 'Sep 28', 'Sep 28', 'Sep 29', 'Sep 29', 'Sep 29', 'Sep 30', 'Sep 30', 'Oct 1', 'Oct 1', 'Oct 2', 'Oct 4', 'Oct 4', 'Oct 4', 'Oct 4', 'Oct 5', 'Oct 6', 'Oct 9', 'Oct 9', 'Oct 10', 'Oct 10', 'Oct 11', 'Oct 11', 'Oct 11', 'Oct 11', 'Oct 11', 'Oct 11', 'Oct 11', 'Oct 11', 'Oct 11', 'Oct 11', 'Oct 11', 'Oct 11', 'Oct 11', 'Oct 11', 'Oct 12', 'Oct 13', 'Oct 13', 'Oct 14', 'Oct 14', 'Oct 15', 'Oct 15', 'Oct 15', 'Oct 16', 'Oct 16', 'Oct 17', 'Oct 18', 'Oct 19', 'Oct 24', 'Oct 24', 'Oct 27', ...
# ["New Year's Day", "New Year's Day", 'World Braille Day', 'Epiphany', 'Orthodox Christmas Day', "International Programmers' Day", 'Stephen Foster Memorial Day', 'Orthodox New Year', 'World Religion Day', 'Martin Luther King Jr. Day', 'Martin Luther King Jr. Day', "Robert E. Lee's Birthday", "Robert E. Lee's Birthday", 'Idaho Human Rights Day', 'Civil Rights Day', "Robert E. Lee's Birthday", "Confederate Heroes' Day", 'Inauguration Day', 'Inauguration Day', 'International Day of Education', 'International Customs Day', 'International Day of Commemoration in Memory of the Victims of the Holocaust', "Tu Bishvat/Tu B'Shevat", 'Kansas Day', 'World Leprosy Day', 'National Freedom Day', 'First Day of Black History Month', 'World Wetlands Day', 'Groundhog Day', 'International Day of Human Fraternity', 'World Cancer Day', 'Rosa Parks Day', 'National Wear Red Day', 'International Day of Zero Tolerance for Female Genital Mutilation', 'Super Bowl', 'World Pulses Day', 'International Day of Women and Girls in Science', 'World Day of the Sick', "Lincoln's Birthday", "Lincoln's Birthday", 'Chinese New Year', 'World Radio Day', "Valentine's Day", 'Statehood Day', "Presidents' Day", "Presidents' Day", "Presidents' Day", 'Daisy Gatson Bates Day', "Susan B. Anthony's Birthday", 'Shrove Tuesday/Mardi Gras', 'Shrove Tuesday/Mardi Gras', 'Elizabeth Peratrovich Day', 'Ash Wednesday', 'World Day of Social Justice', 'International Mother Language Day', 'George Rogers Clark Day', 'Purim', 'Linus Pauling Day', 'Zero Discrimination Day', 'Self-Injury Awareness Day', "St. David's Day", 'Casimir Pulaski Day', "First Day of Women's History Month", 'First Day of Irish American Heritage Month', 'Texas Independence Day', 'Read Across America Day', 'Town Meeting Day', 'World Wildlife Day', 'Employee Appreciation Day', "International Women's Day", 'Maha Shivaratri', "Isra and Mi'raj", 'World Kidney Day', 'Daylight Saving Time starts', "St. Patrick's Day", 'Evacuation Day', 'French Language Day', 'International Day of Happiness', 'March Equinox', 'International Day for the Elimination of Racial Discrimination', 'World Poetry Day', 'International Day of Nowruz', 'World Down Syndrome Day', 'International Day of Forests', 'World Water Day', 'World Meteorological Day', 'World Tuberculosis Day', 'International Day for the Right to the Truth concerning Gross Human Rights Violations and for the Dignity of Victims', 'International Day of Remembrance of Slavery Victims and the Transatlantic Slave Trade', 'International Day of Solidarity with Detained and Missing Staff Members', 'Maryland Day', 'Prince Jonah Kuhio Kalanianaole Day', 'Passover Eve', 'Earth Hour', 'Palm Sunday', 'Holi', 'Passover (first day)', "Seward's Day", 'National Vietnam War Veterans Day', "Doctors' Day", 'César Chávez Day', 'Maundy Thursday', "April Fool's Day", 'World Autism Awareness Day', 'Good Friday', 'Pascua Florida Day', 'Holy Saturday', 'Last Day of Passover', "United Nations' Mine Awareness Day", 'Easter Sunday', 'International Day of Conscience', 'Easter Monday', 'International Day of Sport for Development and Peace', 'National Tartan Day', "National Library Workers' Day", "United Nations' World Health Day", 'Day of Remembrance of the Victims of the Rwanda Genocide', 'Yom HaShoah', 'International Day of Human Space Flight', 'Ramadan Starts', "Thomas Jefferson's Birthday", 'World Chagas Disease Day', "Yom Ha'atzmaut", 'Father Damien Day', 'Emancipation Day', 'International Day for Monuments and Sites', "Patriots' Day", 'Chinese Language Day', 'World Creativity and Innovation Day', 'San Jacinto Day', 'Administrative Professionals Day', 'International Girls in ICT Day', 'Earth Day', 'Oklahoma Day', 'Take our Daughters and Sons to Work Day', 'World Book and Copyright Day', 'English Language Day', 'International Day of Multilateralism and Diplomacy for Peace', "International Delegate's Day", 'World Malaria Day', 'World Intellectual Property Day', 'International Chernobyl Disaster Remembrance Day' ...
# Added! What else would you like to do?
# range(0, 501)
# Welcome to the holiday manager.
# What would you like to do?
# 1. Add a Holiday
# 2. Remove a Holiday
# 3. Save Holiday List
# 4. View Holidays
# 5. Exit
# Choosing 6 will force quit the program, and your progress will be lost.
# Please print the number of your choice.2
# DELETE HOLIDAYS
# --------------------
# What is the name of the holiday you'd like to delete?
# birthday
# Do you know what the date for this would be? Please input one
# april 3
# Your entry has been deleted. Thank you.
# range(0, 500)
# Welcome to the holiday manager.
# What would you like to do?
# 1. Add a Holiday
# 2. Remove a Holiday
# 3. Save Holiday List
# 4. View Holidays
# 5. Exit
# Choosing 6 will force quit the program, and your progress will be lost.
# Please print the number of your choice.4
# VIEW HOLIDAYS
# ---------------------
# What week of holidays would you like to view? For the current week, leave it blank.
# 1
# Here are the holidays for the week you requested.
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-10-c0487562b619> in <module>
#      19         SaveHolidays()
#      20     elif choice == 4:
# ---> 21         ViewHolidays()
#      22     elif choice == 5:
#      23         ExitProgram()
#
# <ipython-input-8-83ad71a186a5> in ViewHolidays()
#      18         listObj = []
#      19         with open('holidays.json') as fp:
# ---> 20             listObj = json.load(fp)
#      21             date.isocalendar(listObj)
#      22         monthday = list()
#
# C:\Conda\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# C:\Conda\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# C:\Conda\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# C:\Conda\lib\json\decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 2 column 3 (char 4)

# %% [markdown]
# #
