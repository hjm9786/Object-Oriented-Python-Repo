# %%
#variables go here
choice = 0

# %%
import json
import shutil

# %%
#data scraping:
from bs4 import BeautifulSoup
import requests

def getHTML(url):
    response = requests.get(url)
    return response.content

html = getHTML("https://www.timeanddate.com/holidays/us/")


soup = BeautifulSoup(html, 'html.parser')

table = soup.find('table', attrs = {'class': "table table--left table--inner-borders-rows table--full-width table--sticky table--holidaycountry"})

A = []
B = []
for row in table.find_all_next('tr'):
    datecells = row.find_all('th')
    if len(datecells) ==1:
        A.append(datecells[0].find(text=True))
    namecells = row.find_all('td')
    if len(namecells)==4:
        B.append(namecells[1].find(text=True))

datedictionary = list()

for i in range(len(A)):
    dict={"name": B[i],
         "date": A[i] }
    datedictionary.append(dict)
    
#print(datedictionary)

filename = 'holidays.json'
listObj = []
with open('holidays.json') as fp:
    listObj = json.load(fp)

dict_key = {"date", "name"}
key = str(sorted(dict_key))

datedictionary = [datedictionary, listObj]

with open(filename, 'a') as json_file:
    json.dump(datedictionary, json_file, indent = 3, separators=(',',': '))
# Out:
# [{'name': "New Year's Day", 'date': 'Jan 1'}, {'name': "New Year's Day", 'date': 'Jan 1'}, {'name': 'World Braille Day', 'date': 'Jan 4'}, {'name': 'Epiphany', 'date': 'Jan 6'}, {'name': 'Orthodox Christmas Day', 'date': 'Jan 7'}, {'name': "International Programmers' Day", 'date': 'Jan 7'}, {'name': 'Stephen Foster Memorial Day', 'date': 'Jan 13'}, {'name': 'Orthodox New Year', 'date': 'Jan 14'}, {'name': 'World Religion Day', 'date': 'Jan 17'}, {'name': 'Martin Luther King Jr. Day', 'date': 'Jan 18'}, {'name': 'Martin Luther King Jr. Day', 'date': 'Jan 18'}, {'name': "Robert E. Lee's Birthday", 'date': 'Jan 18'}, {'name': "Robert E. Lee's Birthday", 'date': 'Jan 18'}, {'name': 'Idaho Human Rights Day', 'date': 'Jan 18'}, {'name': 'Civil Rights Day', 'date': 'Jan 18'}, {'name': "Robert E. Lee's Birthday", 'date': 'Jan 19'}, {'name': "Confederate Heroes' Day", 'date': 'Jan 19'}, {'name': 'Inauguration Day', 'date': 'Jan 20'}, {'name': 'Inauguration Day', 'date': 'Jan 20'}, {'name': 'International Day of Education', 'date': 'Jan 24'}, {'name': 'International Customs Day', 'date': 'Jan 26'}, {'name': 'International Day of Commemoration in Memory of the Victims of the Holocaust', 'date': 'Jan 27'}, {'name': "Tu Bishvat/Tu B'Shevat", 'date': 'Jan 28'}, {'name': 'Kansas Day', 'date': 'Jan 29'}, {'name': 'World Leprosy Day', 'date': 'Jan 31'}, {'name': 'National Freedom Day', 'date': 'Feb 1'}, {'name': 'First Day of Black History Month', 'date': 'Feb 1'}, {'name': 'World Wetlands Day', 'date': 'Feb 2'}, {'name': 'Groundhog Day', 'date': 'Feb 2'}, {'name': 'International Day of Human Fraternity', 'date': 'Feb 4'}, {'name': 'World Cancer Day', 'date': 'Feb 4'}, {'name': 'Rosa Parks Day', 'date': 'Feb 4'}, {'name': 'National Wear Red Day', 'date': 'Feb 5'}, {'name': 'International Day of Zero Tolerance for Female Genital Mutilation', 'date': 'Feb 6'}, {'name': 'Super Bowl', 'date': 'Feb 7'}, {'name': 'World Pulses Day', 'date': 'Feb 10'}, {'name': 'International Day of Women and Girls in Science', 'date': 'Feb 11'}, {'name': 'World Day of the Sick', 'date': 'Feb 11'}, {'name': "Lincoln's Birthday", 'date': 'Feb 12'}, {'name': "Lincoln's Birthday", 'date': 'Feb 12'}, {'name': 'Chinese New Year', 'date': 'Feb 12'}, {'name': 'World Radio Day', 'date': 'Feb 13'}, {'name': "Valentine's Day", 'date': 'Feb 14'}, {'name': 'Statehood Day', 'date': 'Feb 14'}, {'name': "Presidents' Day", 'date': 'Feb 15'}, {'name': "Presidents' Day", 'date': 'Feb 15'}, {'name': "Presidents' Day", 'date': 'Feb 15'}, {'name': 'Daisy Gatson Bates Day', 'date': 'Feb 15'}, {'name': "Susan B. Anthony's Birthday", 'date': 'Feb 15'}, {'name': 'Shrove Tuesday/Mardi Gras', 'date': 'Feb 16'}, {'name': 'Shrove Tuesday/Mardi Gras', 'date': 'Feb 16'}, {'name': 'Elizabeth Peratrovich Day', 'date': 'Feb 16'}, {'name': 'Ash Wednesday', 'date': 'Feb 17'}, {'name': 'World Day of Social Justice', 'date': 'Feb 20'}, {'name': 'International Mother Language Day', 'date': 'Feb 21'}, {'name': 'George Rogers Clark Day', 'date': 'Feb 25'}, {'name': 'Purim', 'date': 'Feb 26'}, {'name': 'Linus Pauling Day', 'date': 'Feb 28'}, {'name': 'Zero Discrimination Day', 'date': 'Mar 1'}, {'name': 'Self-Injury Awareness Day', 'date': 'Mar 1'}, {'name': "St. David's Day", 'date': 'Mar 1'}, {'name': 'Casimir Pulaski Day', 'date': 'Mar 1'}, {'name': "First Day of Women's History Month", 'date': 'Mar 1'}, {'name': 'First Day of Irish American Heritage Month', 'date': 'Mar 1'}, {'name': 'Texas Independence Day', 'date': 'Mar 2'}, {'name': 'Read Across America Day', 'date': 'Mar 2'}, {'name': 'Town Meeting Day', 'date': 'Mar 2'}, {'name': 'World Wildlife Day', 'date': 'Mar 3'}, {'name': 'Employee Appreciation Day', 'date': 'Mar 5'}, {'name': "International Women's Day", 'date': 'Mar 8'}, {'name': 'Maha Shivaratri', 'date': 'Mar 11'}, {'name': "Isra and Mi'raj", 'date': 'Mar 11'}, {'name': 'World Kidney Day', 'date': 'Mar 11'}, {'name': 'Daylight Saving Time starts', 'date': 'Mar 14'}, {'name': "St. Patrick's ...

# %%
#Holday Class

class Holiday:
    def __init__(self, name, date):
        self.name = name
        self.date = date
        
    def get_name(self):
        return self._name
    
    def set_name(self):
        self.name = [name]
        
    def get_date(self):
        return self.date
    
    def set_date(self):
        self.date = [date]
        
    def display_holiday(self):
        print(name, date)
        
    def write_holiday(self, name, date):
        filename = 'holidays.json'
        listObj = []
        with open('holidays.json') as fp:
            listObj = json.load(fp)
        A = []
        A.append(date)
        B = []
        B.append(name)
        adddictionary = list() 
        
        for i in range(len(A)):
            dict={"name": B[i],
             "date": A[i] }
        adddictionary.append(dict)
        print(adddictionary)
        
        
        filename = 'holidays.json'
        listObj = []
        with open('holidays.json') as fp:
            listObj = json.load(fp)

        
        with open(filename, 'a') as json_file:
            json.dump(adddictionary, json_file,
            indent = 3,
            separators=(',',': '))
        

    def remove_holiday(self, name):
        C = []
        C.append(name)
        filename = 'holidays.json'
        obj = json.load(open("holidays.json"))
        if name in C:
            C.pop()
                
        open(filename, 'a').write(
            json.dumps(obj, sort_keys=True, indent=1, separators=(',', ': '))
        )

# %%
#Choice 1 section
def AddHolidays():
    print("ADD HOLIDAYS")
    print("--------------------")
    print("What is the name of the holiday you would like to add?")
    name = input()
    print("What is the date of that holiday?")
    date = input()
    print("Are you sure you'd like to add this? Please enter y for yes and n for no.")
    addchoice = input()
    if addchoice == 'y':
        print("Got it! Adding the holiday...")
        addholiday = Holiday(name, date)
        Holiday(name, date).write_holiday(name, date)
        print("Added! What else would you like to do?")
    elif addchoice == 'n':
        print("Understood. Anything else you want to do?")
    else:
        print("Sorry, I couldn't understand that. Would you like to do anything else?")

# %%
#Choice 2 section
def DeleteHolidays():
    print("DELETE HOLIDAYS")
    print("--------------------")
    print("What is the name of the holiday you'd like to delete?")
    name = input()
    Holiday(name, date).remove_holiday(name)
    print("Thank you!")

# %%
#Choice 3 section
def SaveHolidays():
    print("SAVE HOLIDAYS")
    print("---------------------")
    print("Would you like to save your changes to a copy of the file? Press y for yes, and n for no.")
    savechoice = input()
    if savechoice == 'y':
        print("Great! Saving your changes...")
        src_path = r"holidays.json"
        dst_path = r"holidayscopy.json"
        shutil.copy(src_path, dst_path)
        print("All done!! Your changes have been saved.")
    elif savechoice == 'n':
        print("Alright! Your save has been cancelled.")
    else:
        print("That was not a valid input. Please use a valid input next time.")

# %%
#Choice 4 section
def ViewHolidays():
    print("VIEW HOLIDAYS")
    print("---------------------")
    print("What week of holidays would you like to view? For the current week, leave it blank.")
    week = input()
    if week is None:
        print("Here are this week's holidays, and the weather:")
        open('holidays.json', 'r')
        filename = 'holidays.json'
        listObj = []
        with open('holidays.json') as fp:
            weather = 'api.openweathermap.org/data/2.5/forecast?q={Minneapolis}&appid={1b406ed29a106e93ed43408e778ecd5d}'
            print(weather)
    else:
        print("Here are the holidays for the week you requested.")
        listObj = []
        with open('holidays.json') as fp:
            listObj = json.load(fp)
            date.isocalendar(listObj)
        monthday = list()
        D = []
        D.append(date)
        for i in range(len(listObj)):
        dict={"Date": D[i]}
        result = monthday.append(dict)
        
        print("Here are the holidays that you requested.")
        print(result)
            
    print("What else would you like to do?")

# %%
#Choice 5 section
def ExitProgram():
    global choice
    while choice == 5:
        print("EXIT PROGRAM")
        print("---------------------")
        print("Are you sure you want to exit? [y/n]")
        exit = input()
        if exit == 'y':
            print("Thank you for using Holiday Manager! See you again soon.")
            choice = 6
        elif exit == 'n':
            print("Alright, what would you like to do now?")

# %%
while choice != 6:
    print("Welcome to the holiday manager.")
    print("What would you like to do?")
    print("1. Add a Holiday")
    print("2. Remove a Holiday")
    print("3. Save Holiday List")
    print("4. View Holidays")
    print("5. Exit")
    print("Choosing 6 will force quit the program, and your progress will be lost. ")
    choice = int(input("Please print the number of your choice."))
    if choice == 1:
        AddHolidays()   
    elif choice == 2:
        DeleteHolidays()
    elif choice == 3:
        SaveHolidays()
    elif choice == 4:
        ViewHolidays()
    elif choice == 5:
        ExitProgram()
# Out:
# Welcome to the holiday manager.
# What would you like to do?
# 1. Add a Holiday
# 2. Remove a Holiday
# 3. Save Holiday List
# 4. View Holidays
# 5. Exit
# Choosing 6 will force quit the program, and your progress will be lost.
